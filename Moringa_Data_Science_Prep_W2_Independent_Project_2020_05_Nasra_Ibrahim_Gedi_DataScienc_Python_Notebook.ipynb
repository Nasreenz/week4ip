# %%
# We will first load the sql extension into our environment
# %load_ext sql

# Then connect to our in memory sqlite database
# NB: This database will cease to exist as soon as the database connection is closed. 
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
# Importing the libraries we will need 

# Importing the Pandas Library
#
import pandas as pd

# Importing the Numpy Library
#
import numpy as np

# %%
# Let's read the data from the CSV file and create the dataframe to be used
# 
df = pd.read_csv('Autolib_dataset.csv')
df
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 25 columns]

# %%
vals2 = np.array([1, np.nan, 3, 4]) 
vals2.dtype
# Out:
# dtype('float64')

# %%
# dropping collumns with NaN values in them
df.dropna(axis='columns')
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 23 columns]

# %%
# viewing the collumn
# df['Public name']
df['hour']
# Out:
# 0       11
# 1        7
# 2       20
# 3        4
# 4       17
#         ..
# 4995    11
# 4996    16
# 4997     7
# 4998    17
# 4999    10
# Name: hour, Length: 5000, dtype: int64

# %%
g = df.groupby(["year", "month", "hour"])

# %%
>>> df = pd.read_csv('Autolib_dataset.csv', parse_dates='Fecha', dayfirst=True, index_col=0, sep="\s+")
>>> df['PreciAcu']['2011-01'].count()
31
>>> df.resample("M").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9e763f149010> in <module>()
# ----> 1 monthly=df.resample('M', how='mean')
#
# TypeError: resample() got an unexpected keyword argument 'how'
